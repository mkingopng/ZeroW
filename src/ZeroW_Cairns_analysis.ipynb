# %%
import pandas as pd

# %%
file_path = './../data/paypa_plane/Cairns_Customer_Details_Report_2024-07-21.csv'

# %%
df = pd.read_csv(file_path)
df
# Out:
#                            EMAIL FIRST_NAME LAST_NAME  CITY  STATE COUNTRY  \
# 0     Bishalbhujel0802@gmail.com     Bishal    Bhujel   NaN    NaN      AU
# 1      siobhanbartonpt@gmail.com    Siobhan    Barton   NaN    NaN      AU
# 2          samara9304@icloud.com    Samara      Elmer   NaN    NaN      AU
# 3           jmlinton13@gmail.com        Joy    Linton   NaN    NaN      AU
# 4       melissakelly@hotmail.com   Melissa      Kelly   NaN    NaN      AU
# ..                           ...        ...       ...   ...    ...     ...
# 347  tennillefalappi@hotmail.com   Tennille   Falappi   NaN    NaN      AU
# 348             saclayton@me.com    Stephen    Clyton   NaN    NaN      AU
# 349        phylissmado@gmail.com    Phyliss      Mado   NaN    NaN      AU
# 350          gemery440@gmail.com      Grace     Emery   NaN    NaN      AU
# 351      cameron_fraser@live.com   Cameron     Fraser   NaN    NaN      AU
#
#      POSTCODE  PHONE        MOBILE  ACCOUNT_REF   STATUS
# ...

# %%
# Filter out rows where STATUS == 'Cancelled'
filtered_df = df[df['STATUS'] != 'Cancelled']
filtered_df
# Out:
#                            EMAIL FIRST_NAME LAST_NAME  CITY  STATE COUNTRY  \
# 0     Bishalbhujel0802@gmail.com     Bishal    Bhujel   NaN    NaN      AU
# 1      siobhanbartonpt@gmail.com    Siobhan    Barton   NaN    NaN      AU
# 2          samara9304@icloud.com    Samara      Elmer   NaN    NaN      AU
# 3           jmlinton13@gmail.com        Joy    Linton   NaN    NaN      AU
# 4       melissakelly@hotmail.com   Melissa      Kelly   NaN    NaN      AU
# ..                           ...        ...       ...   ...    ...     ...
# 347  tennillefalappi@hotmail.com   Tennille   Falappi   NaN    NaN      AU
# 348             saclayton@me.com    Stephen    Clyton   NaN    NaN      AU
# 349        phylissmado@gmail.com    Phyliss      Mado   NaN    NaN      AU
# 350          gemery440@gmail.com      Grace     Emery   NaN    NaN      AU
# 351      cameron_fraser@live.com   Cameron     Fraser   NaN    NaN      AU
#
#      POSTCODE  PHONE        MOBILE  ACCOUNT_REF   STATUS
# ...

# %% [markdown]
# This is not correct
