# %%
import pandas as pd

# %%
file_path = './../data/paypa_plane/ZeroW_Arundel members 2024-07-01.csv'

# %%
df = pd.read_csv(file_path)
df
# Out:
#     AGREED_DATE  START_DATE       TYPE      STATUS      METHOD  \
# 0    2020-05-18  2020-05-21  Recurring   Cancelled        Visa
# 1    2020-05-19  2020-06-01  Recurring      Active        Visa
# 2    2020-05-19  2020-06-01  Recurring   Cancelled  Mastercard
# 3    2020-05-23  2020-05-25  Recurring   Cancelled    DE Debit
# 4    2020-05-27  2020-06-12  Recurring   Cancelled    DE Debit
# ..          ...         ...        ...         ...         ...
# 582  2024-06-30  2024-07-01  Recurring      Active  Mastercard
# 583  2024-07-01  2024-07-01  Recurring      Active        Visa
# 584  2024-07-15  2024-07-15  Recurring      Active        Visa
# 585  2024-07-15  2024-07-15  Recurring      Active        Visa
# 586  2024-07-17  2024-07-22  Recurring  In Transit        Visa
#
#               CUSTOMER  REFERENCE PAYMENT_REQUEST  NEXT_PAYMENT  \
# 0         Jenna Osmond        NaN    7riat633h2fw           0.0
# 1        Kayden Weller        NaN    6bf184nv8thv         300.0
# ...

# %%
# Filter out rows where STATUS is 'Cancelled'
filtered_df = df[df['STATUS'] != 'Cancelled']
filtered_df
# Out:
#     AGREED_DATE  START_DATE       TYPE      STATUS      METHOD  \
# 1    2020-05-19  2020-06-01  Recurring      Active        Visa
# 51   2020-06-30  2020-07-01  Recurring      Active        Visa
# 83   2020-08-03  2020-08-03  Recurring      Active        Visa
# 103  2020-09-14  2020-09-14  Recurring      Paused  Mastercard
# 123  2020-11-01  2020-11-01  Recurring      Paused        Visa
# ..          ...         ...        ...         ...         ...
# 582  2024-06-30  2024-07-01  Recurring      Active  Mastercard
# 583  2024-07-01  2024-07-01  Recurring      Active        Visa
# 584  2024-07-15  2024-07-15  Recurring      Active        Visa
# 585  2024-07-15  2024-07-15  Recurring      Active        Visa
# 586  2024-07-17  2024-07-22  Recurring  In Transit        Visa
#
#               CUSTOMER  REFERENCE PAYMENT_REQUEST  NEXT_PAYMENT  \
# 1        Kayden Weller        NaN    6bf184nv8thv         300.0
# 51     Arian Behbehani        NaN    9xv4wi1zhmv4         360.0
# ...

# %%
# number of rows where STATUS is 'Active'
df[df['STATUS'] == 'Active'].shape[0]
# Out:
# 56

# %%
# number of rows where STATUS is 'Paused'
df[df['STATUS'] == 'Paused'].shape[0]
# Out:
# 47

# %%
# number of rows where STATUS is 'Suspended'
df[df['STATUS'] == 'Suspended'].shape[0]
# Out:
# 1

# %%
# number of rows where STATUS is 'In Care'
df[df['STATUS'] == 'In Care'].shape[0]
# Out:
# 0

# %%
# number of rows where STATUS is 'In Transit'
df[df['STATUS'] == 'In Transit'].shape[0]
# Out:
# 1

# %%
filtered_df.to_csv('./../data/paypa_plane/ZeroW_Arundel members 2024-07-01.csv', index=False)
